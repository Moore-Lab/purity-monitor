# %%
import redpitaya_mca as mca
import matplotlib.pyplot as plt

# %%
rp = mca.mca()
#rp.command(22,1)
#print(rp.rx_txt(chunksize=4))
dat = rp.read_histo_data(chan=1)
print(len(dat))
#rp.close()

plt.figure()
plt.plot(dat)
plt.show()
# Out:
# b'
# ...

# %%
# Out:
# b'
# ...

# %%
rp.close()
